# %% [markdown]
# Organizando o diretorio

# %%
#main.py - arquivo principal. é boa pratica que receba esse nome
#src - source . Aquilo que precisa ser adquirido. Classes e funcoes

# %% [markdown]
# Criando novas pastas dentro do docker, pelo terminal

# %% [markdown]
# $ docker exec ac292005cde8 ls -> mostra todas as pastas dentro do docker acessado pelo ID ac292005cde8

# %%
docker exec ac292005cde8 ls # mostra todas as pastas dentro do docker acessado pelo ID ac292005cde8

# %%
##Faz nova pasta no docker
docker exec ac292005cde8 mkdir NOME ARQUIVO

# %%
##Faz novo arquivo no docker
docker exec ac292005cde8 code .app_pratica/main.py#vscode

# %%
#leitura de arquivo
docker exec ac292005cde8 python app_pratica/main.py
# Out:
#   Cell In[2], line 2
#     docker exec ac292005cde8 .app_pratica/main.py
#            ^
# SyntaxError: Missing parentheses in call to 'exec'. Did you mean exec(...)?

# %%
pip install pydantic
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
